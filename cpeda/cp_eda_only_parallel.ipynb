# %%
from eda import get_objectives, get_constraints, non_dominated_sort, non_dominated, assign_crowding_distance, binary_tournament_selection, sample_population, cleanupsamples, generate_example_data, organize_results
from numpy import random
import numpy as np
from scipy.stats import gamma, norm
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from scipy.stats import multivariate_normal as mvn
from scipy.spatial.distance import jensenshannon
from numba import jit
import math
from hdf5storage import loadmat, savemat
import pickle

# %%
# utility functions
def transform_items_to_z(items):
    alpha = np.empty(items.shape[1])
    beta = np.empty(items.shape[1])
    items_z = np.empty(items.shape)
    items_r = items + 1
    for i in range(items_r.shape[1]):
        a, loc, scale = gamma.fit(items_r[:, i], floc=0.0)
        alpha[i] = a
        beta[i] = scale
        u = gamma.cdf(items_r[:,i], a = a, scale = scale)
        u = np.clip(u, 1e-12, 1-1e-12)
        items_z[:,i] = norm.ppf(u) 
    return alpha, beta, items_z

def fit_gamma_y_to_z(YY, XX_z):
    N, T, d = YY.shape
    YY_z = np.empty((N, T, d), dtype=float)
    YY_z[:, 0, :] = XX_z[:, 0, :] 
    shape = np.full((T-1, d), np.nan)
    location = np.full((T-1, d), np.nan)
    scale = np.full((T-1, d), np.nan)
    for t in range(1, T):
        for i in range(d):
            y = YY[:, t, i]
            y_r = y + 1

            if np.ptp(y_r) < 1e-12:
                # raise RuntimeError(
                #     f"Gamma degenerate at t={t}, i={i}\n"
                #     f"unique(y_r)={np.unique(y_r)}\n"
                #     f"min={y_r.min()}, max={y_r.max()}\n"
                #     f"population size={YY.shape[0]}"
                #     f"XX_z= {XX_z[:,t,i]}"
                # )
                print(f"Gamma degenerate at t={t}, i={i}")
                m = float(np.mean(y_r))
                m = max(m, 1e-12)
                std = 1e-5 * m
                v = std * std
                a = (m * m) / v          # shape
                b = v / m                # scale
                loc = 0.0
            else:
                a, loc, b = gamma.fit(y_r, floc=0.0)

            u = gamma.cdf(y_r, a=a, loc=loc, scale=b)
            u = np.clip(u, 1e-12, 1 - 1e-12)
            YY_z[:, t, i] = norm.ppf(u)
            shape[t-1, i] = a
            location[t-1, i] = loc
            scale[t-1, i] = b
    return YY_z, shape, location, scale

def get_norm_cumu_objectives(items, items_z, population, n_selected, n_obj, n_con, rng, if_initial):  # can modify to use objectives instead of population
    XX = np.empty((population.shape[0], n_selected, n_obj+n_con))
    XX_z = np.empty((population.shape[0], n_selected, n_obj+n_con))
    for k in range(population.shape[0]):
        if if_initial:
            qx = rng.permutation(population[k, :]) # permutation only for initial population
        else:
            qx = population[k, :]
        XX[k,:,:] = items[qx,:]
        XX_z[k,:,:] = items_z[qx,:]
    YY = np.cumsum(XX, axis = 1)
    YY_z, shape, location, scale = fit_gamma_y_to_z(YY, XX_z)
    return XX, XX_z, YY, YY_z, shape, location, scale

def fit_markov_in_y_by_t(X, Y):
    K, N, d = X.shape
    A_list = np.zeros((N-1, d, d))
    b_list = np.zeros((N-1, d))
    Q_list = np.zeros((N-1, d, d))
    R2_list = np.zeros(N-1)
    reg_list = []

    for t in range(1, N):  
        S_t = Y[:, t-1, :]  
        Z_t = X[:, t,   :] 

        reg_t = LinearRegression(fit_intercept=True)
        reg_t.fit(S_t, Z_t)
        A_t = reg_t.coef_      # (d, d)
        b_t = reg_t.intercept_ # (d,)
        Z_hat_t = reg_t.predict(S_t)
        R_t = Z_t - Z_hat_t
        Q_t = np.cov(R_t, rowvar=False, bias=False)
        r2 = reg_t.score(S_t, Z_t)

        A_list[t-1, :, :] = A_t
        b_list[t-1, :] = b_t
        Q_list[t-1, :, :] = Q_t
        R2_list[t-1] = r2
        reg_list.append(reg_t)
    params = {"A": A_list,"b": b_list,"Q": Q_list,"regs": reg_list,"R2": R2_list}
    return params

def fit_conditional(items, items_z, population, n_selected, n_obj, n_con, rng, if_initial):
    objectives, objectives_z, cumu_objectives, cumu_objectives_z, shape, location, scale = get_norm_cumu_objectives(items, items_z, population, 
                                                                                                                        n_selected, n_obj, n_con, 
                                                                                                                        rng, if_initial)
    dist_params = fit_markov_in_y_by_t(objectives_z, cumu_objectives_z)
    return objectives_z, dist_params, shape, location, scale

def conditional_density_given_Y_and_t(X_candidates, y_normal, params_time, t):
    A_all = params_time["A"]  
    b_all = params_time["b"]  
    Q_all = params_time["Q"]  

    A_t = A_all[t-1]
    b_t = b_all[t-1]
    Q_t = Q_all[t-1]
    X_candidates = np.asarray(X_candidates)
    y_normal = np.asarray(y_normal).reshape(-1)
    mean_t = A_t @ y_normal + b_t
    Q_t = Q_t + 1e-3 * np.eye(Q_t.shape[0])
    
    densities = mvn.pdf(X_candidates, mean=mean_t, cov=Q_t)
    return densities

def base_rate_model(items_z, XX_0):
    mean0 = np.mean(XX_0, axis = 0)
    Sigma0 = np.cov(XX_0.T) 
    # add regularization to diagonal for singularity
    Sigma0 = Sigma0 + 1e-3 * np.eye(Sigma0.shape[0])
    mvn0 = mvn(mean=mean0, cov=Sigma0)
    x_candidates = items_z
    probabilities = mvn0.pdf(x_candidates)
    probabilities = (probabilities+1e-12)/sum(probabilities+1e-12)
    return probabilities

# %%
# parallel processing sampling
import multiprocessing
from functools import partial

def _sample_chunk(
    seed, chunk_size, 
    samples, samples_z, objectives_z, dist_params, 
    shape, location, scale, if_converged,
    n_selected, n_obj, n_con, capacity, 
    print_every=5000,
):
    rng = np.random.default_rng(seed)
    population = np.zeros((chunk_size, n_selected), dtype=np.int32)
    n_items = samples.shape[0]

    pop_count = 0
    total_attempts = 0
    while pop_count < chunk_size:
        total_attempts += 1

        knapsack_indices = np.zeros(n_selected, dtype=int)    
        knapsack = np.zeros((n_selected,(n_obj+n_con)))
        
        if if_converged:
            probabilities = base_rate_model(samples_z, objectives_z[:, 0, :])  # sample first item from base rate model
        else:
            probabilities = np.ones(n_items) / n_items  # sample first item from uniform
        first_choice = rng.choice(n_items, p=probabilities)
        knapsack_indices[0] = first_choice
        knapsack[0, :] = samples[first_choice, :]
        y_prev_z = samples_z[first_choice, :] 
        y_cum = knapsack[0, :].copy()

        for n in range(1, n_selected):
            x_indices = np.setdiff1d(np.arange(n_items), knapsack_indices[:n])  
            x_candidates = samples_z[x_indices, :] 
            densities = conditional_density_given_Y_and_t(x_candidates, y_prev_z, dist_params, n)
            
            # added for robustness
            densities = np.asarray(densities, dtype=float).ravel()
            s = densities.sum()
            if s > 0:
                probabilities = densities / s
            else:
                print(f"Density sum is zero at t={n}")
                probabilities = np.ones_like(densities) / len(densities)

            next_choice = rng.choice(len(probabilities), p=probabilities)
            next_index = x_indices[next_choice]
            knapsack_indices[n] = next_index
            knapsack[n, :] = samples[next_index, :]

            # normalize y
            y_cum += knapsack[n, :]
            u = gamma.cdf(y_cum, a=shape[n-1, :], loc=location[n-1, :], scale=scale[n-1, :])
            u = np.clip(u, 1e-12, 1-1e-12)
            y_prev_z = norm.ppf(u)
        
        constraint = np.sum(samples[knapsack_indices, -1])
        if constraint <= capacity:
            population[pop_count, :] = knapsack_indices
            pop_count += 1
        
        if total_attempts % 5000 == 0:
            print(f"  Worker pid={multiprocessing.current_process().pid}: "
                  f"Sampled {pop_count}/{chunk_size} (Attempts: {total_attempts})", flush=True)

    return population

# %%
def sample_population_conditional_parallel(
    samples, samples_z, objectives_z, dist_params, 
    shape, location, scale, if_converged, 
    pop_size, n_selected, n_obj, n_con, capacity, rng, 
    n_jobs=None
):

    if n_jobs is None:
        n_jobs = multiprocessing.cpu_count()

    base = pop_size // n_jobs
    rem = pop_size % n_jobs
    chunks = [base] * n_jobs
    for i in range(rem):
        chunks[i] += 1
    chunks = [c for c in chunks if c > 0]
    n_jobs = len(chunks)

    seeds = rng.integers(0, 1_000_000_000, size=n_jobs, dtype=np.int64)
    with multiprocessing.Pool(processes=n_jobs) as pool:
        func = partial(
            _sample_chunk,
            samples=samples,
            samples_z=samples_z,
            objectives_z=objectives_z,
            dist_params=dist_params,
            shape=shape,
            location=location,
            scale=scale,
            if_converged=if_converged,
            n_selected=n_selected,
            n_obj=n_obj,
            n_con=n_con,
            capacity=capacity,
        )
        results = pool.starmap(func, zip(seeds.tolist(), chunks))

    population = np.vstack(results)
    return population

# %%
class KnapsackEDACond:
    def __init__(self, items, capacity, n_selected, n_obj, n_con, pop_size=1000, 
                 generations=10, max_no_improve_gen=10, max_iters=100, seed=1123):
        self.items = items
        self.capacity = capacity
        self.n_selected = n_selected
        self.n_obj = n_obj
        self.n_con = n_con
        self.pop_size = pop_size
        self.generations = generations
        self.max_no_improve_gen = max_no_improve_gen
        self.max_iters = max_iters
        self.rng = random.default_rng(seed=seed)

        self.items_z = None
        self.shape = None
        self.location = None
        self.scale = None
        self.if_initial = True
        self.if_converged = False

        self.first_item_dist = None
        self.distribution_params = None
        self.selected_population = None  # (pop_size, n_selected)
        self.selected_objectives = None  # (pop_size, n_obj) objective values are summed over solutions
        self.objectives_z = None  # (pop_size, n_selected, n_obj)

        self.distribution_params_table = []
        self.pareto_indices_table = []
        self.pareto_front_table = []
        self.js_div_list = []
        self.converged_pf_table = []
        self.selected_objectives_table = []

    def _generate_initial_population(self):
        n_items = self.items.shape[0]
        distribution = np.ones(n_items) / n_items
        population = sample_population(
            self.items, distribution, self.pop_size, self.n_selected, 
            self.capacity, self.rng
        )
        objectives = get_objectives(self.items, population, self.n_obj)
        
        ranks, fronts = non_dominated_sort(objectives)
        distances_all_solutions = np.zeros(population.shape[0], dtype=float)
        for f in fronts:
            distances = assign_crowding_distance(objectives[f, :])
            distances_all_solutions[f] = distances

        select_indices = np.array([], dtype=int)
        while len(select_indices) < self.pop_size:
            indice = binary_tournament_selection(
                population, ranks, distances_all_solutions, self.rng
            )
            select_indices = np.concatenate([select_indices, np.array([indice])])
        
        selected_population = population[select_indices]
        selected_objectives = objectives[select_indices]

        _, _, self.items_z = transform_items_to_z(self.items)
        self.objectives_z, self.distribution_params, self.shape, self.location, self.scale = fit_conditional(self.items, self.items_z, selected_population, 
                                                                                                                self.n_selected, self.n_obj, self.n_con,
                                                                                                                self.rng, self.if_initial) # may need a different rng
        self.first_item_dist = base_rate_model(self.items_z, self.objectives_z[:, 0, :])
        self.selected_population = selected_population
        self.selected_objectives = selected_objectives

    def _update_distribution(self):
        # sampling
        population = sample_population_conditional_parallel(
            self.items, self.items_z, self.objectives_z, self.distribution_params,
            self.shape, self.location, self.scale, self.if_converged,
            self.pop_size, self.n_selected, self.n_obj, self.n_con, self.capacity, self.rng
        )
        objectives = get_objectives(self.items, population, self.n_obj)
        
        # find current pareto front
        _, fronts_current = non_dominated_sort(objectives)
        pareto_indices = population[fronts_current[0]]
        
        # stack populations
        objectives = np.vstack((self.selected_objectives, objectives))
        population = np.vstack((self.selected_population, population))
        
        # select through non-dominated sorting
        ranks, fronts = non_dominated_sort(objectives)
        select_indices = np.array([], dtype=np.int32)
        for f in fronts:
            if len(select_indices) + len(f) <= self.pop_size:
                select_indices = np.concatenate([select_indices, f])
            else:
                remaining_size = self.pop_size - len(select_indices)
                f_distance = assign_crowding_distance(objectives[f, :])
                sort_indices = np.argsort(f_distance)[::-1]
                remaining = f[sort_indices[:remaining_size]]
                select_indices = np.concatenate([select_indices, remaining])
                break
        selected_population = population[select_indices]
        selected_objectives = objectives[select_indices]
        
        n_training = int(self.pop_size*0.15)
        training_population = selected_population[:n_training]
        
        # update distribution
        self.objectives_z, self.distribution_params, self.shape, self.location, self.scale= fit_conditional(self.items, self.items_z, training_population, 
                                                                                                                self.n_selected, self.n_obj, self.n_con,
                                                                                                                self.rng, self.if_initial)
        
        self.selected_population = selected_population
        self.selected_objectives = selected_objectives

        # compute js divergence
        updated_first_item_dist = base_rate_model(self.items_z, self.objectives_z[:, 0, :])
        self.first_item_dist[self.first_item_dist < 1E-08] = 1E-08
        updated_first_item_dist[updated_first_item_dist < 1E-08] = 1E-08
        js_div = jensenshannon(self.first_item_dist, updated_first_item_dist)**2
        self.first_item_dist = updated_first_item_dist
        
        return pareto_indices, js_div

    def _converged_pf(self):
        # sampling
        population = sample_population_conditional_parallel(
            self.items, self.items_z, self.objectives_z, self.distribution_params,
            self.shape, self.location, self.scale, self.if_converged,
            self.pop_size, self.n_selected, self.n_obj, self.n_con, self.capacity, self.rng)
        objectives = get_objectives(self.items, population, self.n_obj)

        # find current pareto front
        pareto_indices = population[non_dominated(objectives).astype(bool)]
        
        # stack populations
        population = np.unique(np.sort(np.vstack((self.selected_population, population)), axis=1), axis=0)
        objectives = get_objectives(self.items, population, self.n_obj)

        # select through non-dominated
        nd_idx = non_dominated(objectives).astype(bool)
        selected_population = population[nd_idx]
        selected_objectives = objectives[nd_idx]

        # update distribution
        self.objectives_z, self.distribution_params, self.shape, self.location, self.scale = fit_conditional(self.items, self.items_z, selected_population, 
                                                                                                                self.n_selected, self.n_obj, self.n_con,
                                                                                                                self.rng, self.if_initial)
        self.selected_population = selected_population
        self.selected_objectives = selected_objectives    

        # compute js divergence
        updated_first_item_dist = base_rate_model(self.items_z, self.objectives_z[:, 0, :])
        self.first_item_dist[self.first_item_dist < 1E-08] = 1E-08
        updated_first_item_dist[updated_first_item_dist < 1E-08] = 1E-08
        js_div = jensenshannon(self.first_item_dist, updated_first_item_dist)**2
        self.first_item_dist = updated_first_item_dist                                                                         
        
        return pareto_indices, js_div

    def run(self):
        self._generate_initial_population()
        self.if_initial = False
        
        # # Run generations (until convergence)
        # part 1: train on a portion of selected population till base rate converges
        no_improve_gen = 0
        prev_js_div = None
        generation = 0
        min_gens = 30
        while no_improve_gen < self.max_no_improve_gen:
            generation += 1
            print(f"Generation {generation} (no improve count: {no_improve_gen})")
            pareto_indices, js_div = self._update_distribution()
            print(f"number of front 0: {pareto_indices.shape[0]}")

            pareto_front = np.zeros((pareto_indices.shape[0], self.items.shape[1]))
            for k in range(pareto_indices.shape[0]):
                pareto_front[k, :] = np.sum(self.items[pareto_indices[k, :], :], axis=0)
                
            self.distribution_params_table.append(self.distribution_params.copy())
            self.pareto_indices_table.append(pareto_indices.copy())
            self.pareto_front_table.append(pareto_front.copy())
            self.js_div_list.append(js_div)
            self.selected_objectives_table.append(self.selected_objectives.copy())
                
            # convergence criteria
            if prev_js_div is not None:
                diff = prev_js_div - js_div
                if generation > min_gens and np.abs(diff) < 0.005: 
                # if np.abs(diff) < 0.005:
                    no_improve_gen += 1
                else:
                    no_improve_gen = 0
            else:
                no_improve_gen = 0
            prev_js_div = js_div
        
        # part 2: train on only the non-dominated solutions till pareto front converges
        self.if_converged = True
        no_improve_gen = 0
        counter = 0
        prev_front_0 = None
        while no_improve_gen < self.max_no_improve_gen and counter < self.max_iters:
            counter += 1
            print(f"Iterations {counter} (no improve count: {no_improve_gen})")
            pareto_indices, js_div = self._converged_pf()
            print(f"number of front 0: {pareto_indices.shape[0]}")

            pareto_front = np.zeros((pareto_indices.shape[0], self.items.shape[1]))
            for k in range(pareto_indices.shape[0]):
                pareto_front[k, :] = np.sum(self.items[pareto_indices[k, :], :], axis=0)

            self.distribution_params_table.append(self.distribution_params.copy())
            self.pareto_indices_table.append(pareto_indices.copy())
            self.pareto_front_table.append(pareto_front.copy())
            self.js_div_list.append(js_div)
            self.selected_objectives_table.append(self.selected_objectives.copy())
    
            front_0 = np.unique(self.selected_objectives, axis=0)
            front_0 = front_0[np.lexsort(front_0.T[::-1])]
            # convergence criteria
            if prev_front_0 is not None:
                if np.array_equal(prev_front_0, front_0):
                    no_improve_gen += 1
                else:
                    no_improve_gen = 0
            else:
                no_improve_gen = 0
            
            self.converged_pf_table.append(front_0.copy())
            prev_front_0 = front_0


        return {
            'distribution_params_table': self.distribution_params_table,
            'pareto_indices_table': self.pareto_indices_table,
            'pareto_front_table': self.pareto_front_table,
            'converged_pf_table': self.converged_pf_table,
            'js_div_list': self.js_div_list,
            'objectives_z': self.objectives_z,
            'items_z': self.items_z,
            'shape': self.shape,
            'location': self.location,
            'scale': self.scale,
            'base_rate_dist': self.first_item_dist,
            'selected_objectives_table': self.selected_objectives_table,
            'mode 1 generations': generation,
            'mode 2 generations': counter
        }

# %%
kn = loadmat('/data/knapsack/runA/kn_2_3_allneg_120_12_3.mat')
shape = kn['shape']
scale = kn['scale']
eda_seed = 1223
n_items = 120
n_selected = 12
n_obj = 3
n_con = 1
capacity = int(shape[-1]*scale[-1]*n_selected)
pop_size = 5000
generations = 100 
max_no_improve_gen = 5
max_iters = 100
for i in range(3):
    items = kn['items'][i]

    eda = KnapsackEDACond(
        items=items,
        capacity=capacity,
        n_selected=n_selected,
        n_obj=n_obj,
        n_con=n_con,
        pop_size=pop_size,
        generations=generations,
        max_no_improve_gen=max_no_improve_gen,
        max_iters=max_iters,
        seed=eda_seed
    )

    results = eda.run()
    with open(f'final_para_min30_2_3_{n_items}_{n_selected}_obj{n_obj}_run{i}.pkl', 'wb') as f:
        pickle.dump(results, f)
# Out:
# Generation 1 (no improve count: 0)
# number of front 0: 90
# Generation 2 (no improve count: 0)
# number of front 0: 117
# Generation 3 (no improve count: 0)
# number of front 0: 128
# Generation 4 (no improve count: 0)
# number of front 0: 138
# Generation 5 (no improve count: 0)
# number of front 0: 164
# Generation 6 (no improve count: 0)
# number of front 0: 165
# Generation 7 (no improve count: 0)
# number of front 0: 144
# Generation 8 (no improve count: 0)
# number of front 0: 173
# Generation 9 (no improve count: 0)
# number of front 0: 178
# Generation 10 (no improve count: 0)
# number of front 0: 181
# Generation 11 (no improve count: 0)
# number of front 0: 180
# Generation 12 (no improve count: 0)
# number of front 0: 199
# Generation 13 (no improve count: 0)
# number of front 0: 244
# Generation 14 (no improve count: 0)
# number of front 0: 259
# Generation 15 (no improve count: 0)
# number of front 0: 253
# Generation 16 (no improve count: 0)
# number of front 0: 233
# Generation 17 (no improve count: 0)
# number of front 0: 268
# Generation 18 (no improve count: 0)
# number of front 0: 295
# Generation 19 (no improve count: 0)
# number of front 0: 287
# Generation 20 (no improve count: 0)
# number of front 0: 288
# Generation 21 (no improve count: 0)
# number of front 0: 278
# Generation 22 (no improve count: 0)
# number of front 0: 229
# Generation 23 (no improve count: 0)
# number of front 0: 236
# Generation 24 (no improve count: 0)
# number of front 0: 226
# Generation 25 (no improve count: 0)
# number of front 0: 208
# Generation 26 (no improve count: 0)
# number of front 0: 198
# Generation 27 (no improve count: 0)
# number of front 0: 204
# Generation 28 (no improve count: 0)
# number of front 0: 207
# Generation 29 (no improve count: 0)
# number of front 0: 218
# Generation 30 (no improve count: 0)
# number of front 0: 238
# Generation 31 (no improve count: 0)
# number of front 0: 229
# Generation 32 (no improve count: 1)
# number of front 0: 234
# Generation 33 (no improve count: 2)
# number of front 0: 244
# Generation 34 (no improve count: 3)
# number of front 0: 226
# Generation 35 (no improve count: 4)
# number of front 0: 243
# Iterations 1 (no improve count: 0)
# number of front 0: 317
# Iterations 2 (no improve count: 0)
# number of front 0: 256
# Iterations 3 (no improve count: 0)
# number of front 0: 306
# Iterations 4 (no improve count: 0)
# number of front 0: 306
# Iterations 5 (no improve count: 0)
# number of front 0: 307
# Iterations 6 (no improve count: 0)
# number of front 0: 407
# Iterations 7 (no improve count: 0)
# number of front 0: 415
# Iterations 8 (no improve count: 0)
# number of front 0: 478
# Iterations 9 (no improve count: 0)
# number of front 0: 485
# Iterations 10 (no improve count: 0)
# number of front 0: 503
# Iterations 11 (no improve count: 0)
# number of front 0: 480
# Iterations 12 (no improve count: 0)
# number of front 0: 550
# Iterations 13 (no improve count: 0)
# number of front 0: 496
# Iterations 14 (no improve count: 0)
# number of front 0: 557
# Iterations 15 (no improve count: 0)
# number of front 0: 592
# Iterations 16 (no improve count: 0)
# number of front 0: 607
# Iterations 17 (no improve count: 0)
# number of front 0: 610
# Iterations 18 (no improve count: 0)
# number of front 0: 570
# Iterations 19 (no improve count: 0)
# number of front 0: 595
# Iterations 20 (no improve count: 0)
# number of front 0: 569
# Iterations 21 (no improve count: 0)
# number of front 0: 610
# Iterations 22 (no improve count: 0)
# number of front 0: 524
# Iterations 23 (no improve count: 0)
# number of front 0: 545
# Iterations 24 (no improve count: 0)
# number of front 0: 605
# Iterations 25 (no improve count: 0)
# number of front 0: 556
# Iterations 26 (no improve count: 0)
# number of front 0: 578
# Iterations 27 (no improve count: 0)
# number of front 0: 581
# Iterations 28 (no improve count: 0)
# number of front 0: 500
# Iterations 29 (no improve count: 0)
# number of front 0: 568
# Iterations 30 (no improve count: 0)
# number of front 0: 570
# Iterations 31 (no improve count: 0)
# number of front 0: 553
# Iterations 32 (no improve count: 0)
# number of front 0: 521
# Iterations 33 (no improve count: 0)
# number of front 0: 504
# Iterations 34 (no improve count: 0)
# number of front 0: 541
# Iterations 35 (no improve count: 0)
# number of front 0: 575
# Iterations 36 (no improve count: 0)
# number of front 0: 544
# Iterations 37 (no improve count: 0)
# number of front 0: 571
# Iterations 38 (no improve count: 0)
# number of front 0: 568
# Iterations 39 (no improve count: 0)
# number of front 0: 603
# Iterations 40 (no improve count: 0)
# number of front 0: 545
# Iterations 41 (no improve count: 0)
# number of front 0: 596
# Iterations 42 (no improve count: 0)
# number of front 0: 533
# Iterations 43 (no improve count: 0)
# number of front 0: 538
# Iterations 44 (no improve count: 0)
# number of front 0: 546
# Iterations 45 (no improve count: 0)
# number of front 0: 568
# Iterations 46 (no improve count: 0)
# number of front 0: 523
# Iterations 47 (no improve count: 0)
# number of front 0: 542
# Iterations 48 (no improve count: 0)
# number of front 0: 532
# Iterations 49 (no improve count: 0)
# number of front 0: 512
# Iterations 50 (no improve count: 0)
# number of front 0: 574
# Iterations 51 (no improve count: 0)
# number of front 0: 569
# Iterations 52 (no improve count: 0)
# number of front 0: 511
# Iterations 53 (no improve count: 0)
# number of front 0: 584
# Iterations 54 (no improve count: 0)
# number of front 0: 560
# Iterations 55 (no improve count: 0)
# number of front 0: 576
# Iterations 56 (no improve count: 0)
# number of front 0: 549
# Iterations 57 (no improve count: 0)
# number of front 0: 504
# Iterations 58 (no improve count: 0)
# number of front 0: 587
# Iterations 59 (no improve count: 0)
# number of front 0: 571
# Iterations 60 (no improve count: 0)
# number of front 0: 495
# Iterations 61 (no improve count: 0)
# number of front 0: 587
# Iterations 62 (no improve count: 0)
# number of front 0: 468
# Iterations 63 (no improve count: 0)
# number of front 0: 554
# Iterations 64 (no improve count: 0)
# number of front 0: 550
# Iterations 65 (no improve count: 0)
# number of front 0: 596
# Iterations 66 (no improve count: 0)
# number of front 0: 531
# Iterations 67 (no improve count: 0)
# number of front 0: 544
# Iterations 68 (no improve count: 0)
# number of front 0: 582
# Iterations 69 (no improve count: 0)
# number of front 0: 559
# Iterations 70 (no improve count: 0)
# number of front 0: 583
# Iterations 71 (no improve count: 0)
# number of front 0: 511
# Iterations 72 (no improve count: 0)
# number of front 0: 561
# Iterations 73 (no improve count: 0)
# number of front 0: 575
# Iterations 74 (no improve count: 0)
# number of front 0: 537
# Iterations 75 (no improve count: 0)
# number of front 0: 542
# Iterations 76 (no improve count: 0)
# number of front 0: 536
# Iterations 77 (no improve count: 0)
# number of front 0: 585
# Iterations 78 (no improve count: 0)
# number of front 0: 533
# Iterations 79 (no improve count: 0)
# number of front 0: 556
# Iterations 80 (no improve count: 0)
# number of front 0: 535
# Iterations 81 (no improve count: 0)
# number of front 0: 525
# Iterations 82 (no improve count: 0)
# number of front 0: 539
# Iterations 83 (no improve count: 0)
# number of front 0: 549
# Iterations 84 (no improve count: 0)
# number of front 0: 519
# Iterations 85 (no improve count: 0)
# number of front 0: 586
# Iterations 86 (no improve count: 0)
# number of front 0: 585
# Iterations 87 (no improve count: 0)
# number of front 0: 492
# Iterations 88 (no improve count: 0)
# number of front 0: 518
# Iterations 89 (no improve count: 0)
# number of front 0: 511
# Iterations 90 (no improve count: 0)
# number of front 0: 598
# Iterations 91 (no improve count: 0)
# number of front 0: 584
# Iterations 92 (no improve count: 0)
# number of front 0: 530
# Iterations 93 (no improve count: 0)
# number of front 0: 609
# Iterations 94 (no improve count: 0)
# number of front 0: 587
# Iterations 95 (no improve count: 0)
# number of front 0: 627
# Iterations 96 (no improve count: 0)
# number of front 0: 547
# Iterations 97 (no improve count: 0)
# number of front 0: 549
# Iterations 98 (no improve count: 0)
# number of front 0: 566
# Iterations 99 (no improve count: 0)
# number of front 0: 520
# Iterations 100 (no improve count: 0)
# number of front 0: 605
# Generation 1 (no improve count: 0)
# number of front 0: 94
# Generation 2 (no improve count: 0)
# number of front 0: 137
# Generation 3 (no improve count: 0)
# number of front 0: 145
# Generation 4 (no improve count: 0)
# number of front 0: 141
# Generation 5 (no improve count: 0)
# number of front 0: 154
# Generation 6 (no improve count: 0)
# number of front 0: 160
# Generation 7 (no improve count: 0)
# number of front 0: 164
# Generation 8 (no improve count: 0)
# number of front 0: 195
# Generation 9 (no improve count: 0)
# number of front 0: 216
# Generation 10 (no improve count: 0)
# number of front 0: 223
# Generation 11 (no improve count: 0)
# number of front 0: 199
# Generation 12 (no improve count: 0)
# number of front 0: 226
# Generation 13 (no improve count: 0)
# number of front 0: 273
# Generation 14 (no improve count: 0)
# number of front 0: 258
# Generation 15 (no improve count: 0)
# number of front 0: 278
# Generation 16 (no improve count: 0)
# number of front 0: 292
# Generation 17 (no improve count: 0)
# number of front 0: 230
# Generation 18 (no improve count: 0)
# number of front 0: 252
# Generation 19 (no improve count: 0)
# number of front 0: 252
# Generation 20 (no improve count: 0)
# number of front 0: 237
# Generation 21 (no improve count: 0)
# number of front 0: 258
# Generation 22 (no improve count: 0)
# number of front 0: 261
# Generation 23 (no improve count: 0)
# number of front 0: 262
# Generation 24 (no improve count: 0)
# number of front 0: 322
# Generation 25 (no improve count: 0)
# number of front 0: 309
# Generation 26 (no improve count: 0)
# number of front 0: 359
# Generation 27 (no improve count: 0)
# number of front 0: 368
# Generation 28 (no improve count: 0)
# number of front 0: 475
# Generation 29 (no improve count: 0)
# number of front 0: 486
# Generation 30 (no improve count: 0)
# number of front 0: 535
# Generation 31 (no improve count: 0)
# number of front 0: 520
# Generation 32 (no improve count: 1)
# number of front 0: 639
# Generation 33 (no improve count: 2)
# number of front 0: 595
# Generation 34 (no improve count: 3)
# number of front 0: 526
# Generation 35 (no improve count: 4)
# number of front 0: 607
# Iterations 1 (no improve count: 0)
# number of front 0: 1094
# Iterations 2 (no improve count: 0)
# number of front 0: 302
# Iterations 3 (no improve count: 0)
# number of front 0: 420
# Iterations 4 (no improve count: 0)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815249: Sampled 11/104 (Attempts: 5000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815263: Sampled 16/104 (Attempts: 5000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815245: Sampled 8/104 (Attempts: 5000)  Worker pid=2815243: Sampled 13/104 (Attempts: 5000)
#
#   Worker pid=2815244: Sampled 9/104 (Attempts: 5000)  Worker pid=2815257: Sampled 11/104 (Attempts: 5000)
#
#   Worker pid=2815260: Sampled 4/104 (Attempts: 5000)
#   Worker pid=2815229: Sampled 7/104 (Attempts: 5000)
#   Worker pid=2815258: Sampled 17/104 (Attempts: 5000)
#   Worker pid=2815217: Sampled 13/105 (Attempts: 5000)
#   Worker pid=2815262: Sampled 10/104 (Attempts: 5000)
#   Worker pid=2815228: Sampled 7/104 (Attempts: 5000)
#   Worker pid=2815242: Sampled 16/104 (Attempts: 5000)
# Density sum is zero at t=11
#   Worker pid=2815219: Sampled 10/105 (Attempts: 5000)  Worker pid=2815252: Sampled 8/104 (Attempts: 5000)
#
#   Worker pid=2815225: Sampled 14/104 (Attempts: 5000)
#   Worker pid=2815233: Sampled 9/104 (Attempts: 5000)
#   Worker pid=2815239: Sampled 12/104 (Attempts: 5000)
# Density sum is zero at t=11  Worker pid=2815259: Sampled 17/104 (Attempts: 5000)
#
# Density sum is zero at t=11
#   Worker pid=2815218: Sampled 13/105 (Attempts: 5000)  Worker pid=2815256: Sampled 11/104 (Attempts: 5000)
#   Worker pid=2815253: Sampled 10/104 (Attempts: 5000)
#
#   Worker pid=2815223: Sampled 11/104 (Attempts: 5000)
#   Worker pid=2815255: Sampled 13/104 (Attempts: 5000)
#   Worker pid=2815232: Sampled 12/104 (Attempts: 5000)
#   Worker pid=2815221: Sampled 12/104 (Attempts: 5000)
#   Worker pid=2815214: Sampled 10/105 (Attempts: 5000)
#   Worker pid=2815220: Sampled 12/104 (Attempts: 5000)
#   Worker pid=2815240: Sampled 10/104 (Attempts: 5000)
#   Worker pid=2815224: Sampled 14/104 (Attempts: 5000)
#   Worker pid=2815261: Sampled 11/104 (Attempts: 5000)
#   Worker pid=2815213: Sampled 13/105 (Attempts: 5000)  Worker pid=2815250: Sampled 12/104 (Attempts: 5000)
#
#   Worker pid=2815236: Sampled 8/104 (Attempts: 5000)
#   Worker pid=2815238: Sampled 7/104 (Attempts: 5000)
#   Worker pid=2815230: Sampled 11/104 (Attempts: 5000)
#   Worker pid=2815241: Sampled 9/104 (Attempts: 5000)
#   Worker pid=2815254: Sampled 8/104 (Attempts: 5000)
#   Worker pid=2815227: Sampled 12/104 (Attempts: 5000)  Worker pid=2815234: Sampled 7/104 (Attempts: 5000)
#
#   Worker pid=2815237: Sampled 21/104 (Attempts: 5000)
#   Worker pid=2815235: Sampled 9/104 (Attempts: 5000)
#   Worker pid=2815212: Sampled 10/105 (Attempts: 5000)
#   Worker pid=2815222: Sampled 14/104 (Attempts: 5000)  Worker pid=2815226: Sampled 17/104 (Attempts: 5000)
#
# Density sum is zero at t=11
#   Worker pid=2815215: Sampled 10/105 (Attempts: 5000)
#   Worker pid=2815216: Sampled 11/105 (Attempts: 5000)
#   Worker pid=2815231: Sampled 14/104 (Attempts: 5000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815249: Sampled 18/104 (Attempts: 10000)
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815263: Sampled 20/104 (Attempts: 10000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815243: Sampled 26/104 (Attempts: 10000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815257: Sampled 21/104 (Attempts: 10000)
#   Worker pid=2815260: Sampled 17/104 (Attempts: 10000)
#   Worker pid=2815262: Sampled 19/104 (Attempts: 10000)
# Density sum is zero at t=11
#   Worker pid=2815217: Sampled 22/105 (Attempts: 10000)
#   Worker pid=2815258: Sampled 26/104 (Attempts: 10000)
#   Worker pid=2815218: Sampled 23/105 (Attempts: 10000)
#   Worker pid=2815245: Sampled 21/104 (Attempts: 10000)
# Density sum is zero at t=11  Worker pid=2815252: Sampled 15/104 (Attempts: 10000)
#
#   Worker pid=2815242: Sampled 28/104 (Attempts: 10000)
#   Worker pid=2815250: Sampled 26/104 (Attempts: 10000)
# Density sum is zero at t=11
#   Worker pid=2815244: Sampled 14/104 (Attempts: 10000)  Worker pid=2815261: Sampled 25/104 (Attempts: 10000)
#
#   Worker pid=2815219: Sampled 14/105 (Attempts: 10000)
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815253: Sampled 16/104 (Attempts: 10000)
#   Worker pid=2815214: Sampled 20/105 (Attempts: 10000)
#   Worker pid=2815236: Sampled 25/104 (Attempts: 10000)
#   Worker pid=2815255: Sampled 25/104 (Attempts: 10000)  Worker pid=2815220: Sampled 25/104 (Attempts: 10000)
#
#   Worker pid=2815256: Sampled 24/104 (Attempts: 10000)
#   Worker pid=2815229: Sampled 18/104 (Attempts: 10000)
#   Worker pid=2815239: Sampled 18/104 (Attempts: 10000)
#   Worker pid=2815240: Sampled 15/104 (Attempts: 10000)
#   Worker pid=2815228: Sampled 20/104 (Attempts: 10000)
#   Worker pid=2815213: Sampled 28/105 (Attempts: 10000)
#   Worker pid=2815223: Sampled 29/104 (Attempts: 10000)
#   Worker pid=2815237: Sampled 35/104 (Attempts: 10000)
#   Worker pid=2815232: Sampled 24/104 (Attempts: 10000)Density sum is zero at t=11
#
#   Worker pid=2815238: Sampled 24/104 (Attempts: 10000)
#   Worker pid=2815224: Sampled 21/104 (Attempts: 10000)
#   Worker pid=2815233: Sampled 22/104 (Attempts: 10000)
#   Worker pid=2815221: Sampled 19/104 (Attempts: 10000)
#   Worker pid=2815259: Sampled 31/104 (Attempts: 10000)
#   Worker pid=2815225: Sampled 23/104 (Attempts: 10000)
#   Worker pid=2815230: Sampled 22/104 (Attempts: 10000)Density sum is zero at t=11
#
#   Worker pid=2815241: Sampled 21/104 (Attempts: 10000)
#   Worker pid=2815212: Sampled 28/105 (Attempts: 10000)
#   Worker pid=2815227: Sampled 24/104 (Attempts: 10000)
# Density sum is zero at t=11  Worker pid=2815231: Sampled 31/104 (Attempts: 10000)
#
#   Worker pid=2815226: Sampled 35/104 (Attempts: 10000)
#   Worker pid=2815254: Sampled 17/104 (Attempts: 10000)
#   Worker pid=2815235: Sampled 17/104 (Attempts: 10000)  Worker pid=2815215: Sampled 17/105 (Attempts: 10000)
#
#   Worker pid=2815234: Sampled 13/104 (Attempts: 10000)
# Density sum is zero at t=11
#   Worker pid=2815222: Sampled 29/104 (Attempts: 10000)
# Density sum is zero at t=11Density sum is zero at t=11
#
#   Worker pid=2815216: Sampled 21/105 (Attempts: 10000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815263: Sampled 30/104 (Attempts: 15000)
#   Worker pid=2815249: Sampled 27/104 (Attempts: 15000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815243: Sampled 37/104 (Attempts: 15000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815253: Sampled 26/104 (Attempts: 15000)
#   Worker pid=2815260: Sampled 27/104 (Attempts: 15000)
# Density sum is zero at t=11
#   Worker pid=2815218: Sampled 35/105 (Attempts: 15000)
#   Worker pid=2815257: Sampled 30/104 (Attempts: 15000)
#   Worker pid=2815262: Sampled 33/104 (Attempts: 15000)
# Density sum is zero at t=11
#   Worker pid=2815258: Sampled 39/104 (Attempts: 15000)
#   Worker pid=2815242: Sampled 39/104 (Attempts: 15000)
# Density sum is zero at t=11
#   Worker pid=2815252: Sampled 30/104 (Attempts: 15000)
# Density sum is zero at t=11
#   Worker pid=2815255: Sampled 36/104 (Attempts: 15000)
# Density sum is zero at t=11
#   Worker pid=2815245: Sampled 31/104 (Attempts: 15000)
#   Worker pid=2815232: Sampled 27/104 (Attempts: 15000)
#   Worker pid=2815217: Sampled 30/105 (Attempts: 15000)
#   Worker pid=2815256: Sampled 34/104 (Attempts: 15000)
#   Worker pid=2815219: Sampled 27/105 (Attempts: 15000)
#   Worker pid=2815244: Sampled 23/104 (Attempts: 15000)
#   Worker pid=2815214: Sampled 32/105 (Attempts: 15000)  Worker pid=2815236: Sampled 40/104 (Attempts: 15000)
#
#   Worker pid=2815231: Sampled 34/104 (Attempts: 15000)
#   Worker pid=2815213: Sampled 37/105 (Attempts: 15000)
# Density sum is zero at t=11
#   Worker pid=2815229: Sampled 34/104 (Attempts: 15000)
#   Worker pid=2815239: Sampled 23/104 (Attempts: 15000)
#   Worker pid=2815250: Sampled 36/104 (Attempts: 15000)
#   Worker pid=2815237: Sampled 51/104 (Attempts: 15000)
#   Worker pid=2815223: Sampled 43/104 (Attempts: 15000)
#   Worker pid=2815215: Sampled 25/105 (Attempts: 15000)
#   Worker pid=2815225: Sampled 28/104 (Attempts: 15000)
#   Worker pid=2815224: Sampled 29/104 (Attempts: 15000)
#   Worker pid=2815228: Sampled 38/104 (Attempts: 15000)
#   Worker pid=2815220: Sampled 39/104 (Attempts: 15000)
#   Worker pid=2815261: Sampled 39/104 (Attempts: 15000)
#   Worker pid=2815254: Sampled 20/104 (Attempts: 15000)
#   Worker pid=2815226: Sampled 39/104 (Attempts: 15000)
#   Worker pid=2815238: Sampled 32/104 (Attempts: 15000)
#   Worker pid=2815240: Sampled 26/104 (Attempts: 15000)
#   Worker pid=2815227: Sampled 34/104 (Attempts: 15000)  Worker pid=2815259: Sampled 44/104 (Attempts: 15000)
#
#   Worker pid=2815233: Sampled 38/104 (Attempts: 15000)
#   Worker pid=2815221: Sampled 28/104 (Attempts: 15000)
#   Worker pid=2815222: Sampled 39/104 (Attempts: 15000)
#   Worker pid=2815230: Sampled 32/104 (Attempts: 15000)
#   Worker pid=2815235: Sampled 26/104 (Attempts: 15000)
# Density sum is zero at t=11
#   Worker pid=2815212: Sampled 39/105 (Attempts: 15000)
#   Worker pid=2815216: Sampled 33/105 (Attempts: 15000)
#   Worker pid=2815234: Sampled 21/104 (Attempts: 15000)
#   Worker pid=2815241: Sampled 30/104 (Attempts: 15000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815243: Sampled 53/104 (Attempts: 20000)
#   Worker pid=2815263: Sampled 45/104 (Attempts: 20000)
#   Worker pid=2815249: Sampled 34/104 (Attempts: 20000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815253: Sampled 35/104 (Attempts: 20000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815260: Sampled 37/104 (Attempts: 20000)
#   Worker pid=2815218: Sampled 46/105 (Attempts: 20000)
#   Worker pid=2815258: Sampled 48/104 (Attempts: 20000)
#   Worker pid=2815257: Sampled 37/104 (Attempts: 20000)
#   Worker pid=2815243: Sampled 61/104 (Attempts: 25000)
#   Worker pid=2815262: Sampled 42/104 (Attempts: 20000)
#   Worker pid=2815255: Sampled 49/104 (Attempts: 20000)
#   Worker pid=2815252: Sampled 38/104 (Attempts: 20000)
# Density sum is zero at t=11
#   Worker pid=2815242: Sampled 46/104 (Attempts: 20000)
#   Worker pid=2815232: Sampled 41/104 (Attempts: 20000)
#   Worker pid=2815245: Sampled 41/104 (Attempts: 20000)
# Density sum is zero at t=11
#   Worker pid=2815231: Sampled 39/104 (Attempts: 20000)
#   Worker pid=2815236: Sampled 51/104 (Attempts: 20000)
#   Worker pid=2815237: Sampled 59/104 (Attempts: 20000)
#   Worker pid=2815229: Sampled 45/104 (Attempts: 20000)
#   Worker pid=2815219: Sampled 29/105 (Attempts: 20000)
#   Worker pid=2815217: Sampled 33/105 (Attempts: 20000)
#   Worker pid=2815256: Sampled 43/104 (Attempts: 20000)
#   Worker pid=2815214: Sampled 44/105 (Attempts: 20000)
#   Worker pid=2815224: Sampled 36/104 (Attempts: 20000)
#   Worker pid=2815244: Sampled 29/104 (Attempts: 20000)
#   Worker pid=2815215: Sampled 37/105 (Attempts: 20000)
#   Worker pid=2815259: Sampled 58/104 (Attempts: 20000)
#   Worker pid=2815213: Sampled 53/105 (Attempts: 20000)
#   Worker pid=2815233: Sampled 43/104 (Attempts: 20000)
#   Worker pid=2815239: Sampled 35/104 (Attempts: 20000)
#   Worker pid=2815254: Sampled 28/104 (Attempts: 20000)
#   Worker pid=2815220: Sampled 53/104 (Attempts: 20000)
#   Worker pid=2815238: Sampled 49/104 (Attempts: 20000)
#   Worker pid=2815227: Sampled 44/104 (Attempts: 20000)
#   Worker pid=2815240: Sampled 34/104 (Attempts: 20000)  Worker pid=2815226: Sampled 47/104 (Attempts: 20000)
#
#   Worker pid=2815261: Sampled 48/104 (Attempts: 20000)
# Density sum is zero at t=11
#   Worker pid=2815228: Sampled 54/104 (Attempts: 20000)
#   Worker pid=2815250: Sampled 46/104 (Attempts: 20000)
#   Worker pid=2815225: Sampled 38/104 (Attempts: 20000)
# Density sum is zero at t=11
#   Worker pid=2815223: Sampled 51/104 (Attempts: 20000)
# Density sum is zero at t=11
#   Worker pid=2815230: Sampled 40/104 (Attempts: 20000)
#   Worker pid=2815222: Sampled 54/104 (Attempts: 20000)
#   Worker pid=2815221: Sampled 43/104 (Attempts: 20000)  Worker pid=2815216: Sampled 46/105 (Attempts: 20000)
#
#   Worker pid=2815212: Sampled 48/105 (Attempts: 20000)
#   Worker pid=2815241: Sampled 45/104 (Attempts: 20000)  Worker pid=2815235: Sampled 38/104 (Attempts: 20000)
#
#   Worker pid=2815234: Sampled 37/104 (Attempts: 20000)
#   Worker pid=2815263: Sampled 52/104 (Attempts: 25000)
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815249: Sampled 42/104 (Attempts: 25000)
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815253: Sampled 42/104 (Attempts: 25000)
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815243: Sampled 66/104 (Attempts: 30000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11  Worker pid=2815255: Sampled 63/104 (Attempts: 25000)
#
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815242: Sampled 60/104 (Attempts: 25000)
#   Worker pid=2815258: Sampled 65/104 (Attempts: 25000)
#   Worker pid=2815257: Sampled 49/104 (Attempts: 25000)
#   Worker pid=2815252: Sampled 47/104 (Attempts: 25000)
# Density sum is zero at t=11
#   Worker pid=2815218: Sampled 56/105 (Attempts: 25000)
# Density sum is zero at t=11
#   Worker pid=2815260: Sampled 47/104 (Attempts: 25000)
#   Worker pid=2815231: Sampled 48/104 (Attempts: 25000)
#   Worker pid=2815245: Sampled 55/104 (Attempts: 25000)
# Density sum is zero at t=11Density sum is zero at t=11
#
#   Worker pid=2815229: Sampled 60/104 (Attempts: 25000)
# Density sum is zero at t=11  Worker pid=2815214: Sampled 49/105 (Attempts: 25000)
#
#   Worker pid=2815262: Sampled 57/104 (Attempts: 25000)
#   Worker pid=2815232: Sampled 59/104 (Attempts: 25000)
#   Worker pid=2815224: Sampled 46/104 (Attempts: 25000)
#   Worker pid=2815236: Sampled 66/104 (Attempts: 25000)
#   Worker pid=2815219: Sampled 36/105 (Attempts: 25000)
#   Worker pid=2815220: Sampled 62/104 (Attempts: 25000)
#   Worker pid=2815256: Sampled 56/104 (Attempts: 25000)
#   Worker pid=2815217: Sampled 47/105 (Attempts: 25000)
#   Worker pid=2815239: Sampled 45/104 (Attempts: 25000)  Worker pid=2815237: Sampled 73/104 (Attempts: 25000)
#
#   Worker pid=2815244: Sampled 41/104 (Attempts: 25000)
# Density sum is zero at t=11
#   Worker pid=2815238: Sampled 59/104 (Attempts: 25000)
#   Worker pid=2815215: Sampled 47/105 (Attempts: 25000)
#   Worker pid=2815233: Sampled 55/104 (Attempts: 25000)  Worker pid=2815261: Sampled 63/104 (Attempts: 25000)
#   Worker pid=2815253: Sampled 58/104 (Attempts: 30000)
#   Worker pid=2815250: Sampled 54/104 (Attempts: 25000)
#
#   Worker pid=2815213: Sampled 67/105 (Attempts: 25000)
# Density sum is zero at t=11
#   Worker pid=2815259: Sampled 62/104 (Attempts: 25000)
#   Worker pid=2815230: Sampled 49/104 (Attempts: 25000)
# Density sum is zero at t=11  Worker pid=2815225: Sampled 50/104 (Attempts: 25000)
#
#   Worker pid=2815240: Sampled 48/104 (Attempts: 25000)
#   Worker pid=2815223: Sampled 59/104 (Attempts: 25000)
#   Worker pid=2815226: Sampled 61/104 (Attempts: 25000)
#   Worker pid=2815227: Sampled 59/104 (Attempts: 25000)  Worker pid=2815254: Sampled 42/104 (Attempts: 25000)
#
#   Worker pid=2815235: Sampled 54/104 (Attempts: 25000)  Worker pid=2815228: Sampled 63/104 (Attempts: 25000)
#
#   Worker pid=2815221: Sampled 53/104 (Attempts: 25000)
# Density sum is zero at t=11
#   Worker pid=2815222: Sampled 69/104 (Attempts: 25000)
#   Worker pid=2815216: Sampled 62/105 (Attempts: 25000)
# Density sum is zero at t=11
#   Worker pid=2815212: Sampled 57/105 (Attempts: 25000)
#   Worker pid=2815241: Sampled 62/104 (Attempts: 25000)
#   Worker pid=2815234: Sampled 42/104 (Attempts: 25000)
#   Worker pid=2815263: Sampled 59/104 (Attempts: 30000)
#   Worker pid=2815249: Sampled 51/104 (Attempts: 30000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815243: Sampled 77/104 (Attempts: 35000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815242: Sampled 71/104 (Attempts: 30000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11  Worker pid=2815253: Sampled 62/104 (Attempts: 35000)
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815257: Sampled 61/104 (Attempts: 30000)
#   Worker pid=2815260: Sampled 62/104 (Attempts: 30000)
#   Worker pid=2815255: Sampled 70/104 (Attempts: 30000)
# Density sum is zero at t=11
#   Worker pid=2815258: Sampled 68/104 (Attempts: 30000)
#   Worker pid=2815231: Sampled 62/104 (Attempts: 30000)
# Density sum is zero at t=11
#   Worker pid=2815224: Sampled 53/104 (Attempts: 30000)
#   Worker pid=2815214: Sampled 64/105 (Attempts: 30000)
#   Worker pid=2815252: Sampled 54/104 (Attempts: 30000)
#   Worker pid=2815229: Sampled 76/104 (Attempts: 30000)  Worker pid=2815245: Sampled 66/104 (Attempts: 30000)
#
#   Worker pid=2815218: Sampled 65/105 (Attempts: 30000)
#   Worker pid=2815232: Sampled 67/104 (Attempts: 30000)
#   Worker pid=2815236: Sampled 72/104 (Attempts: 30000)
# Density sum is zero at t=11
#   Worker pid=2815262: Sampled 64/104 (Attempts: 30000)
#   Worker pid=2815219: Sampled 43/105 (Attempts: 30000)
# Density sum is zero at t=11  Worker pid=2815238: Sampled 63/104 (Attempts: 30000)
#
# Density sum is zero at t=11
#   Worker pid=2815237: Sampled 87/104 (Attempts: 30000)
#   Worker pid=2815244: Sampled 52/104 (Attempts: 30000)
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815256: Sampled 62/104 (Attempts: 30000)
#   Worker pid=2815230: Sampled 60/104 (Attempts: 30000)Density sum is zero at t=11
#
#   Worker pid=2815220: Sampled 79/104 (Attempts: 30000)
#   Worker pid=2815250: Sampled 66/104 (Attempts: 30000)
#   Worker pid=2815225: Sampled 64/104 (Attempts: 30000)
#   Worker pid=2815217: Sampled 60/105 (Attempts: 30000)
#   Worker pid=2815240: Sampled 65/104 (Attempts: 30000)
#   Worker pid=2815215: Sampled 67/105 (Attempts: 30000)
#   Worker pid=2815213: Sampled 70/105 (Attempts: 30000)
#   Worker pid=2815226: Sampled 68/104 (Attempts: 30000)
#   Worker pid=2815233: Sampled 68/104 (Attempts: 30000)
#   Worker pid=2815239: Sampled 55/104 (Attempts: 30000)
# Density sum is zero at t=11  Worker pid=2815223: Sampled 66/104 (Attempts: 30000)
#
#   Worker pid=2815261: Sampled 75/104 (Attempts: 30000)
#   Worker pid=2815259: Sampled 72/104 (Attempts: 30000)
#   Worker pid=2815227: Sampled 68/104 (Attempts: 30000)
# Density sum is zero at t=11
#   Worker pid=2815221: Sampled 62/104 (Attempts: 30000)
# Density sum is zero at t=11
#   Worker pid=2815235: Sampled 65/104 (Attempts: 30000)
# Density sum is zero at t=11
#   Worker pid=2815216: Sampled 77/105 (Attempts: 30000)
#   Worker pid=2815254: Sampled 47/104 (Attempts: 30000)
#   Worker pid=2815212: Sampled 68/105 (Attempts: 30000)
# Density sum is zero at t=11
#   Worker pid=2815228: Sampled 75/104 (Attempts: 30000)
#   Worker pid=2815222: Sampled 80/104 (Attempts: 30000)
#   Worker pid=2815241: Sampled 71/104 (Attempts: 30000)
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815234: Sampled 55/104 (Attempts: 30000)
# Density sum is zero at t=11
#   Worker pid=2815263: Sampled 74/104 (Attempts: 35000)
#   Worker pid=2815243: Sampled 88/104 (Attempts: 40000)
# Density sum is zero at t=11Density sum is zero at t=11
#
#   Worker pid=2815249: Sampled 66/104 (Attempts: 35000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815253: Sampled 71/104 (Attempts: 40000)
#   Worker pid=2815242: Sampled 82/104 (Attempts: 35000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815260: Sampled 71/104 (Attempts: 35000)
# Density sum is zero at t=11
#   Worker pid=2815255: Sampled 81/104 (Attempts: 35000)
#   Worker pid=2815231: Sampled 69/104 (Attempts: 35000)
#   Worker pid=2815258: Sampled 76/104 (Attempts: 35000)
#   Worker pid=2815257: Sampled 76/104 (Attempts: 35000)
#   Worker pid=2815214: Sampled 80/105 (Attempts: 35000)
#   Worker pid=2815252: Sampled 65/104 (Attempts: 35000)  Worker pid=2815229: Sampled 88/104 (Attempts: 35000)
#
#   Worker pid=2815243: Sampled 101/104 (Attempts: 45000)  Worker pid=2815232: Sampled 81/104 (Attempts: 35000)
#
#   Worker pid=2815224: Sampled 65/104 (Attempts: 35000)
#   Worker pid=2815238: Sampled 77/104 (Attempts: 35000)
#   Worker pid=2815219: Sampled 58/105 (Attempts: 35000)
#   Worker pid=2815237: Sampled 96/104 (Attempts: 35000)
#   Worker pid=2815245: Sampled 75/104 (Attempts: 35000)
# Density sum is zero at t=11
#   Worker pid=2815218: Sampled 81/105 (Attempts: 35000)
#   Worker pid=2815230: Sampled 68/104 (Attempts: 35000)
#   Worker pid=2815244: Sampled 61/104 (Attempts: 35000)  Worker pid=2815262: Sampled 77/104 (Attempts: 35000)
#
#   Worker pid=2815236: Sampled 87/104 (Attempts: 35000)
# Density sum is zero at t=11
#   Worker pid=2815256: Sampled 77/104 (Attempts: 35000)
#   Worker pid=2815225: Sampled 75/104 (Attempts: 35000)
#   Worker pid=2815217: Sampled 77/105 (Attempts: 35000)
# Density sum is zero at t=11
#   Worker pid=2815215: Sampled 80/105 (Attempts: 35000)
# Density sum is zero at t=11  Worker pid=2815213: Sampled 83/105 (Attempts: 35000)
#
#   Worker pid=2815250: Sampled 77/104 (Attempts: 35000)
#   Worker pid=2815220: Sampled 90/104 (Attempts: 35000)Density sum is zero at t=11
#
# Density sum is zero at t=11
#   Worker pid=2815239: Sampled 65/104 (Attempts: 35000)
#   Worker pid=2815221: Sampled 70/104 (Attempts: 35000)
#   Worker pid=2815226: Sampled 78/104 (Attempts: 35000)
#   Worker pid=2815259: Sampled 84/104 (Attempts: 35000)
#   Worker pid=2815240: Sampled 75/104 (Attempts: 35000)
#   Worker pid=2815233: Sampled 79/104 (Attempts: 35000)
# Density sum is zero at t=11
#   Worker pid=2815223: Sampled 76/104 (Attempts: 35000)
#   Worker pid=2815216: Sampled 87/105 (Attempts: 35000)
#   Worker pid=2815212: Sampled 77/105 (Attempts: 35000)
#   Worker pid=2815254: Sampled 58/104 (Attempts: 35000)
#   Worker pid=2815227: Sampled 71/104 (Attempts: 35000)
# Density sum is zero at t=11
#   Worker pid=2815228: Sampled 86/104 (Attempts: 35000)
#   Worker pid=2815222: Sampled 96/104 (Attempts: 35000)
#   Worker pid=2815263: Sampled 86/104 (Attempts: 40000)
#   Worker pid=2815241: Sampled 81/104 (Attempts: 35000)
#   Worker pid=2815234: Sampled 62/104 (Attempts: 35000)
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815261: Sampled 98/104 (Attempts: 35000)
#   Worker pid=2815235: Sampled 83/104 (Attempts: 35000)
# Density sum is zero at t=11
#   Worker pid=2815249: Sampled 79/104 (Attempts: 40000)
#   Worker pid=2815253: Sampled 79/104 (Attempts: 45000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815242: Sampled 94/104 (Attempts: 40000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815260: Sampled 77/104 (Attempts: 40000)
#   Worker pid=2815231: Sampled 81/104 (Attempts: 40000)
#   Worker pid=2815257: Sampled 91/104 (Attempts: 40000)
#   Worker pid=2815214: Sampled 89/105 (Attempts: 40000)
# Density sum is zero at t=11
#   Worker pid=2815255: Sampled 97/104 (Attempts: 40000)
#   Worker pid=2815224: Sampled 77/104 (Attempts: 40000)
#   Worker pid=2815258: Sampled 88/104 (Attempts: 40000)
#   Worker pid=2815252: Sampled 81/104 (Attempts: 40000)
#   Worker pid=2815238: Sampled 92/104 (Attempts: 40000)
#   Worker pid=2815219: Sampled 61/105 (Attempts: 40000)
#   Worker pid=2815230: Sampled 76/104 (Attempts: 40000)
#   Worker pid=2815245: Sampled 85/104 (Attempts: 40000)
#   Worker pid=2815232: Sampled 94/104 (Attempts: 40000)
# Density sum is zero at t=11
#   Worker pid=2815244: Sampled 76/104 (Attempts: 40000)
#   Worker pid=2815229: Sampled 92/104 (Attempts: 40000)
#   Worker pid=2815236: Sampled 94/104 (Attempts: 40000)
#   Worker pid=2815262: Sampled 92/104 (Attempts: 40000)
# Density sum is zero at t=11
#   Worker pid=2815218: Sampled 95/105 (Attempts: 40000)
#   Worker pid=2815256: Sampled 91/104 (Attempts: 40000)
#   Worker pid=2815225: Sampled 84/104 (Attempts: 40000)
#   Worker pid=2815217: Sampled 87/105 (Attempts: 40000)
# Density sum is zero at t=11
#   Worker pid=2815215: Sampled 90/105 (Attempts: 40000)
#   Worker pid=2815253: Sampled 85/104 (Attempts: 50000)
#   Worker pid=2815220: Sampled 103/104 (Attempts: 40000)
#   Worker pid=2815213: Sampled 91/105 (Attempts: 40000)
# Density sum is zero at t=11
#   Worker pid=2815250: Sampled 85/104 (Attempts: 40000)
#   Worker pid=2815221: Sampled 83/104 (Attempts: 40000)
#   Worker pid=2815226: Sampled 93/104 (Attempts: 40000)
# Density sum is zero at t=11
#   Worker pid=2815240: Sampled 89/104 (Attempts: 40000)
#   Worker pid=2815239: Sampled 75/104 (Attempts: 40000)
#   Worker pid=2815223: Sampled 85/104 (Attempts: 40000)
#   Worker pid=2815233: Sampled 84/104 (Attempts: 40000)
#   Worker pid=2815212: Sampled 89/105 (Attempts: 40000)
#   Worker pid=2815263: Sampled 95/104 (Attempts: 45000)
#   Worker pid=2815216: Sampled 97/105 (Attempts: 40000)
#   Worker pid=2815259: Sampled 92/104 (Attempts: 40000)
#   Worker pid=2815227: Sampled 82/104 (Attempts: 40000)
#   Worker pid=2815254: Sampled 68/104 (Attempts: 40000)
#   Worker pid=2815228: Sampled 103/104 (Attempts: 40000)
#   Worker pid=2815234: Sampled 71/104 (Attempts: 40000)
#   Worker pid=2815241: Sampled 92/104 (Attempts: 40000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815235: Sampled 101/104 (Attempts: 40000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815249: Sampled 90/104 (Attempts: 45000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815260: Sampled 88/104 (Attempts: 45000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815245: Sampled 99/104 (Attempts: 45000)
#   Worker pid=2815224: Sampled 90/104 (Attempts: 45000)
#   Worker pid=2815231: Sampled 91/104 (Attempts: 45000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815238: Sampled 100/104 (Attempts: 45000)
#   Worker pid=2815226: Sampled 102/104 (Attempts: 45000)
#   Worker pid=2815262: Sampled 103/104 (Attempts: 45000)
#   Worker pid=2815218: Sampled 104/105 (Attempts: 45000)
#   Worker pid=2815257: Sampled 101/104 (Attempts: 45000)
#   Worker pid=2815239: Sampled 85/104 (Attempts: 45000)
#   Worker pid=2815258: Sampled 100/104 (Attempts: 45000)
# Density sum is zero at t=11
#   Worker pid=2815252: Sampled 90/104 (Attempts: 45000)
#   Worker pid=2815234: Sampled 78/104 (Attempts: 45000)
#   Worker pid=2815236: Sampled 103/104 (Attempts: 45000)
#   Worker pid=2815230: Sampled 85/104 (Attempts: 45000)
#   Worker pid=2815219: Sampled 69/105 (Attempts: 45000)
#   Worker pid=2815232: Sampled 102/104 (Attempts: 45000)
#   Worker pid=2815244: Sampled 89/104 (Attempts: 45000)
#   Worker pid=2815217: Sampled 98/105 (Attempts: 45000)
#   Worker pid=2815229: Sampled 101/104 (Attempts: 45000)
#   Worker pid=2815256: Sampled 102/104 (Attempts: 45000)
#   Worker pid=2815213: Sampled 101/105 (Attempts: 45000)
#   Worker pid=2815240: Sampled 102/104 (Attempts: 45000)
#   Worker pid=2815215: Sampled 101/105 (Attempts: 45000)
#   Worker pid=2815225: Sampled 96/104 (Attempts: 45000)
#   Worker pid=2815263: Sampled 102/104 (Attempts: 50000)
# Density sum is zero at t=11
#   Worker pid=2815253: Sampled 99/104 (Attempts: 55000)
#   Worker pid=2815233: Sampled 93/104 (Attempts: 45000)
#   Worker pid=2815223: Sampled 92/104 (Attempts: 45000)
#   Worker pid=2815221: Sampled 92/104 (Attempts: 45000)
#   Worker pid=2815250: Sampled 102/104 (Attempts: 45000)
#   Worker pid=2815259: Sampled 98/104 (Attempts: 45000)
#   Worker pid=2815241: Sampled 101/104 (Attempts: 45000)
#   Worker pid=2815212: Sampled 96/105 (Attempts: 45000)
#   Worker pid=2815227: Sampled 90/104 (Attempts: 45000)
#   Worker pid=2815254: Sampled 82/104 (Attempts: 45000)
#   Worker pid=2815249: Sampled 99/104 (Attempts: 50000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815224: Sampled 95/104 (Attempts: 50000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815239: Sampled 98/104 (Attempts: 50000)
#   Worker pid=2815234: Sampled 89/104 (Attempts: 50000)
#   Worker pid=2815217: Sampled 103/105 (Attempts: 50000)
#   Worker pid=2815252: Sampled 102/104 (Attempts: 50000)
#   Worker pid=2815219: Sampled 76/105 (Attempts: 50000)
# Density sum is zero at t=11
#   Worker pid=2815230: Sampled 95/104 (Attempts: 50000)
#   Worker pid=2815244: Sampled 97/104 (Attempts: 50000)
#   Worker pid=2815233: Sampled 98/104 (Attempts: 50000)
#   Worker pid=2815223: Sampled 97/104 (Attempts: 50000)
#   Worker pid=2815227: Sampled 100/104 (Attempts: 50000)
#   Worker pid=2815254: Sampled 101/104 (Attempts: 50000)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
#   Worker pid=2815234: Sampled 99/104 (Attempts: 55000)
#   Worker pid=2815219: Sampled 86/105 (Attempts: 55000)
#   Worker pid=2815233: Sampled 103/104 (Attempts: 55000)
# Density sum is zero at t=11
#   Worker pid=2815219: Sampled 96/105 (Attempts: 60000)
# Density sum is zero at t=11
# number of front 0: 918
# Iterations 5 (no improve count: 0)
# number of front 0: 401
# Iterations 6 (no improve count: 0)
# number of front 0: 663
# Iterations 7 (no improve count: 0)
# number of front 0: 957
# Iterations 8 (no improve count: 0)
# Density sum is zero at t=11
# number of front 0: 1124
# Iterations 9 (no improve count: 0)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# number of front 0: 1097
# Iterations 10 (no improve count: 0)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# number of front 0: 1273
# Iterations 11 (no improve count: 0)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# number of front 0: 1197
# Iterations 12 (no improve count: 0)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# number of front 0: 1299
# Iterations 13 (no improve count: 0)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# number of front 0: 1319
# Iterations 14 (no improve count: 0)
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11Density sum is zero at t=11
#
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Density sum is zero at t=11
# Process ForkPoolWorker-8818:
# Process ForkPoolWorker-8825:
# Process ForkPoolWorker-8806:
# Process ForkPoolWorker-8797:
# Process ForkPoolWorker-8804:
# Process ForkPoolWorker-8813:
# Process ForkPoolWorker-8821:
# Process ForkPoolWorker-8819:
# Process ForkPoolWorker-8811:
# Process ForkPoolWorker-8800:
# Process ForkPoolWorker-8817:
# Process ForkPoolWorker-8828:
# Process ForkPoolWorker-8798:
# Density sum is zero at t=11
# Process ForkPoolWorker-8808:
# Process ForkPoolWorker-8809:
# Process ForkPoolWorker-8815:
# Process ForkPoolWorker-8820:
# Process ForkPoolWorker-8807:
# Process ForkPoolWorker-8832:
# Process ForkPoolWorker-8831:
# Process ForkPoolWorker-8824:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 30
#      15 items = kn['items'][i]
#      17 eda = KnapsackEDACond(
#      18     items=items,
#      19     capacity=capacity,
#    (...)     27     seed=eda_seed
#      28 )
# ---> 30 results = eda.run()
#      31 with open(f'final_para_min30_2_3_{n_items}_{n_selected}_obj{n_obj}_run{i}.pkl', 'wb') as f:
#      32     pickle.dump(results, f)
#
# Cell In[30], line 203, in KnapsackEDACond.run(self)
#     201 counter += 1
#     202 print(f"Iterations {counter} (no improve count: {no_improve_gen})")
# --> 203 pareto_indices, js_div = self._converged_pf()
#     204 print(f"number of front 0: {pareto_indices.shape[0]}")
#     206 pareto_front = np.zeros((pareto_indices.shape[0], self.items.shape[1]))
#
# Cell In[30], line 123, in KnapsackEDACond._converged_pf(self)
#     121 def _converged_pf(self):
#     122     # sampling
# --> 123     population = sample_population_conditional_parallel(
#     124         self.items, self.items_z, self.objectives_z, self.distribution_params,
#     125         self.shape, self.location, self.scale, self.if_converged,
#     126         self.pop_size, self.n_selected, self.n_obj, self.n_con, self.capacity, self.rng)
#     127     objectives = get_objectives(self.items, population, self.n_obj)
#     129     # find current pareto front
#
# Cell In[28], line 36, in sample_population_conditional_parallel(samples, samples_z, objectives_z, dist_params, shape, location, scale, if_converged, pop_size, n_selected, n_obj, n_con, capacity, rng, n_jobs)
#      20 with multiprocessing.Pool(processes=n_jobs) as pool:
#      21     func = partial(
#      22         _sample_chunk,
#      23         samples=samples,
#    (...)     34         capacity=capacity,
#      35     )
# ---> 36     results = pool.starmap(func, zip(seeds.tolist(), chunks))
#      38 population = np.vstack(results)
#      39 return population
#
# File ~/anaconda3/envs/numba_env/lib/python3.12/multiprocessing/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File ~/anaconda3/envs/numba_env/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/anaconda3/envs/numba_env/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/anaconda3/envs/numba_env/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/anaconda3/envs/numba_env/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
# compare to NSGA eda
run = 2
n_items = 120
n_selected = 12
n_obj = 3

kn = loadmat(f'/data/knapsack/runA/kn_2_3_allneg_{n_items}_{n_selected}_{n_obj}.mat')
pf_old = kn['pareto_front_final'][run]

with open(f'/data/knapsack/cpeda/results_final/final_2_3_{n_items}_{n_selected}_obj{n_obj}_run{run}.pkl', 'rb') as f:
    results = pickle.load(f)
pf_cpeda = results['converged_pf_table'][-1]

with open(f'final_para_2_3_{n_items}_{n_selected}_obj{n_obj}_run{run}.pkl', 'rb') as f:
    results_para = pickle.load(f)
pf_cpeda_para = results_para['converged_pf_table'][-1]

# %%
from matplotlib import pyplot as plt
# %matplotlib widget
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(projection='3d')
ax.plot(pf_old[:,0], pf_old[:,1], pf_old[:,2], 'rs', alpha=0.5, markersize=5)
ax.plot(pf_cpeda[:,0], pf_cpeda[:,1], pf_cpeda[:,2], 'go', alpha=0.7, markersize=5)
ax.plot(pf_cpeda_para[:,0], pf_cpeda_para[:,1], pf_cpeda_para[:,2], 'bo', alpha=0.7, markersize=5)
ax.set_xlabel('Obj 1')
ax.set_ylabel('Obj 2')
ax.set_zlabel('Obj 3')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pf_predicted = pf_cpeda_para
pf_actual = pf_cpeda
dominated = np.zeros(len(pf_predicted))
for i in range(len(pf_predicted)):
    for j in range(len(pf_actual)):
        if np.all(pf_actual[j, :n_obj] >= pf_predicted[i, :n_obj]) and \
            np.any(pf_actual[j, :n_obj] > pf_predicted[i, :n_obj]):
            dominated[i] = 1
            break
np.sum(dominated)/len(pf_predicted)
# Out:
# 0.6853080568720379

# %%
from pymoo.indicators.hv import HV

A = pf_cpeda_para[:, :n_obj].astype(np.float64)
B = pf_cpeda[:, :n_obj].astype(np.float64)
C = pf_old[:, :n_obj].astype(np.float64)
A_min = -A
B_min = -B
C_min = -C

ref = np.zeros(n_obj)
hv = HV(ref_point=ref)

A_hv = hv(A_min)
B_hv = hv(B_min)
C_hv = hv(C_min)

print(A_hv)
print(B_hv)
print(C_hv)
print((A_hv-B_hv)/B_hv)
print((A_hv-C_hv)/C_hv)
print((B_hv-C_hv)/C_hv)
# Out:
# 2644240.0
# 2691624.0
# 2892770.0
# -0.01760424190005736
# -0.08591419297075122
# -0.06953404522309067
