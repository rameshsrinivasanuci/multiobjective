# %%
from hdf5storage import loadmat, savemat
from numpy import random
from eda import get_objectives, get_constraints, sample_population
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
kn= loadmat('results/knapsack_eda_sim_2pair5000_120_6_all.mat')
kn.keys()
# Out:
# dict_keys(['capacity', 'items', 'max_no_improve_gen', 'n_con', 'n_items', 'n_obj', 'n_selected', 'pareto_front_final', 'pareto_indices_final', 'pop_size', 'r', 'scale', 'shape'])

# %%
pf = kn['pareto_front_final']

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(pf[0][:,0], pf[0][:,1],pf[0][:,2], 'ro')
ax.plot(pf[1][:,0], pf[1][:,1],pf[1][:,2], 'go')
ax.plot(pf[2][:,0], pf[2][:,1],pf[2][:,2], 'bo')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pf[2]
# Out:
# array([[ 34, 101,  33,  48],
#        [ 10, 119,  46,  48],
#        [ 10, 124,  44,  48],
#        ...,
#        [ 67,  31,  26,  48],
#        [ 68,  27,  24,  47],
#        [ 71,  26,  22,  47]], dtype=int16)

# %%
""" 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Example data
X, Y = np.meshgrid(np.linspace(-5, 5, 10), np.linspace(-5, 5, 10))
Z = np.sin(np.sqrt(X**2 + Y**2))

ax.plot_surface(X, Y, Z, cmap='viridis')
plt.show()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Example data
X, Y = np.meshgrid(np.linspace(-5, 5, 10), np.linspace(-5, 5, 10))
Z = np.sin(np.sqrt(X**2 + Y**2))

ax.plot_surface(X, Y, Z, cmap='viridis')
plt.show() """
# Out:
# " \nimport matplotlib.pyplot as plt\nfrom mpl_toolkits.mplot3d import Axes3D\nimport numpy as np\n\nfig = plt.figure()\nax = fig.add_subplot(111, projection='3d')\n\n# Example data\nX, Y = np.meshgrid(np.linspace(-5, 5, 10), np.linspace(-5, 5, 10))\nZ = np.sin(np.sqrt(X**2 + Y**2))\n\nax.plot_surface(X, Y, Z, cmap='viridis')\nplt.show()\n\nfig = plt.figure()\nax = fig.add_subplot(111, projection='3d')\n\n# Example data\nX, Y = np.meshgrid(np.linspace(-5, 5, 10), np.linspace(-5, 5, 10))\nZ = np.sin(np.sqrt(X**2 + Y**2))\n\nax.plot_surface(X, Y, Z, cmap='viridis')\nplt.show() "
