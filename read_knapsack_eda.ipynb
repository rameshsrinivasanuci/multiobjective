# %%
from hdf5storage import loadmat, savemat
from numpy import random
import numpy as np
x = loadmat('./results/knapsack_eda_sim_15_5.mat')
x.keys()
# Out:
# dict_keys(['capacity', 'distribution_table', 'eda_seed', 'items', 'items_seed', 'js_div_list', 'max_no_improve_gen', 'n_con', 'n_items', 'n_obj', 'n_selected', 'pareto_front_table', 'pareto_indices_table', 'pop_size', 'r', 'scale', 'shape'])

# %%
y = np.vstack(x['distribution_table'])
from matplotlib import pyplot as plt
plt.plot(y)
plt.show()

# %%
y = x['pareto_indices_table']
print(y[0])
# Out:
# [[ 1  3  4  6  9]
#  [ 1  3  4  8  9]
#  [ 1  3  4  9 14]
#  [ 1  4  6  9 12]
#  [ 1  4  8  9 14]
#  [ 3  4  8  9 14]
#  [ 3  4  9 12 14]
#  [ 3  9 10 12 14]
#  [ 4  7  9 12 14]
#  [ 4  8  9 10 14]
#  [ 4  8  9 11 14]
#  [ 7  8  9 12 14]
#  [ 8  9 11 12 14]]

# %%
print(y[-10].shape)
# Out:
# (13, 5)
